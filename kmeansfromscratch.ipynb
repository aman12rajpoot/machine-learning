# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('student_clustering.csv')

# %%
df.head()
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
x=df.iloc[:,:].values

# %%
x.shape
# Out:
# (200, 2)

# %%
import random
import numpy as np
class KMeans:
    def __init__(self,n_clusters=2,max_iter=100):
        self.n_clusters=n_clusters
        self.max_iter=max_iter
        self.centroids=None
    def fit_predict(self,x):
        random_index=random.sample(range(0,x.shape[0]),self.n_clusters)
        self.centroids=x[random_index]
        for k in range (0,self.max_iter):
            
            
            
            
           z=self.assign_clusters(x)
           p=self.move_centroids(x,z)
           if(self.centroids==p).all():
               break
            
        return z
            
            
        
        
        
        # move_centroids()
        
    def assign_clusters(self,x):
        clusters=[]
        distances=[]
        for row in x:
            for i in self.centroids:
                distance=np.sqrt(np.dot(row-i,row-i))
                distances.append(distance)
            min_dist=min(distances)
            clusters.append(distances.index(min_dist))
            distances.clear()
        return np.array(clusters)
        
    def move_centroids(self,x,clusters):
        no_clusters=np.unique(clusters)
        for n in no_clusters:
            new_centroids=x[clusters==n].mean(axis=0)
        return new_centroids
    # def check(self):
    #     if (self.centroids==new_centroids.all()):
    #         return new_centroids
    #     else:
    #         assign_clusters()

# %%
y_means=obj.fit_predict(x)

# %%
plt.scatter(x[y_means == 0,0],x[y_means == 0,1],color='red')
plt.scatter(x[y_means == 1,0],x[y_means == 1,1],color='blue')
plt.scatter(x[y_means == 2,0],x[y_means == 2,1],color='green')
plt.scatter(x[y_means == 3,0],x[y_means == 3,1],color='yellow')
